# %% [markdown]
# **Kemampuan Akhir Tiap Tahapan Belajar(sub CPMK)**
#
# SCPMK 1681902: Mahasiswa dapat menjelaskan tahapan KDD  [CPMK19]
#
# **Indikator**
# Mahasiswa dapat melakukan operasi pada dataset (membaca data, struktur dataframe)

# %% [markdown]
# Tuliskan Identitas Anda!
#
# Nim: 21.11.3910<br>
# Nama: Haikal Raditya Fadhilah<br>
# Kelas: Informatika 02<br>
#
# Rename File Anda dengan menambahkan **4 digit nim anda** di akhir nama file

# %%
#dictionary
buku= {"judul":"disperately seeking paradise", "penulis":"Ziauddin Sardar"}
buku
# Out:
# {'judul': 'disperately seeking paradise', 'penulis': 'Ziauddin Sardar'}

# %% [markdown]
# 1. a. pada dictionary **buku**, manakah yang berfungsi sebagai key?<br>
#    b. pada dictionary **buku**, tunjukkan valuenya!

# %%
# Write your code below and press Shift+Enter to execute
# Nomer 1.a
print(buku.keys())
# Out:
# dict_keys(['judul', 'penulis'])

# %%
# Nomer 1.b
print(buku.values())
# Out:
# dict_values(['disperately seeking paradise', 'Ziauddin Sardar'])

# %%
#dictionary
transaksi={"pulpen":5000,"buku":7000,"pensil":3000}

# %% [markdown]
# 2. a. tampilkan harga pensil<br>
# b. tampilkan total transaksi

# %%
# Nomer 2.a
print("Harga Pensil : ", transaksi['pensil'])
# Out:
# Harga Pensil :  3000

# %%
#Nomer 2.b
print ("Total Transaksi : ",transaksi['pulpen'] + transaksi['pensil'] + transaksi['buku'])
# Out:
# Total Transaksi :  15000

# %%
#tuple
matakuliah = ("big data", "data mining", "kecerdasan buatan", "statistika", "algoritma dan pemrograman", "pemrograman web")
matakuliah
# Out:
# ('big data',
#  'data mining',
#  'kecerdasan buatan',
#  'statistika',
#  'algoritma dan pemrograman',
#  'pemrograman web')

# %% [markdown]
# 3. a. berapa panjang tuple **matakuliah**<br>
# b. tampilkan element terakhir dari tuple **matakuliah**

# %%
# Nomer 3.a
print("Jumlah Value Dari Tuple matakuliah : ",len(matakuliah))
# Out:
# Jumlah Value Dari Tuple matakuliah :  6

# %%
# Nomer 3.b
print("Elemen Terakhir Dari Tuple matakuliah : ", matakuliah[len(matakuliah) - 1])
# Out:
# Elemen Terakhir Dari Tuple matakuliah :  pemrograman web

# %%
# list
buah=["pisang", "anggur","mangga"]

# %% [markdown]
# 4. a. tambahkan buah **jeruk, kelengkeng**, apel kedalam list **buah** tersebut! tampilkan isi data list **buah** tersebut<br>
# b. hapus data buah **pisang** dari list tersebut<br>
# c. urutkan element buah tersebut secara **descending**

# %%
# Nomer 4.a
tambahan = ["jeruk","kelengkeng"]
for x in tambahan:
  buah.append(x)
print(buah)
# Out:
# ['pisang', 'anggur', 'mangga', 'jeruk', 'kelengkeng']

# %%
# Nomer 4.b
buah.remove("pisang")
print(buah)
# Out:
# ['anggur', 'mangga', 'jeruk', 'kelengkeng']

# %%
# Nomer 4.c
buah.sort(reverse=True)
buah
# Out:
# ['mangga', 'kelengkeng', 'jeruk', 'anggur']

# %% [markdown]
# ![soal jadwal.png](data:image/png;base64,...)

# %% [markdown]
# 5. a. buatlah dataframe dari representasi tabel di atas<br>
# b. tampilkan jadwal praktikum saja<br>
# c. tampilkan data **hari, jam, ruang dan kelas**<br>
# d. tampilan data **jam dan ruang** dari **kelas praktikum** yang anda ikuti

# %%
import pandas as pd

# %%
# Nomer 5.a
jadwalPraktikum = [
    {"HARI" : "SELASA","JAM" : "08:50 - 10:30","RUANG" : "07.01.02", "KODE" : "ST168","MATA KULIAH" : "BIG DATA DAN DATA MINING","KELAS" : "21S1IF-BigData2(ST168)"},
    {"HARI" : "SELASA","JAM" : "10:40 - 12:20","RUANG" : "07.02.01", "KODE" : "ST168","MATA KULIAH" : "BIG DATA DAN DATA MINING","KELAS" : "21S1IF-BigData1(ST168)"},
    {"HARI" : "SELASA","JAM" : "12:20 - 15:00","RUANG" : "06.02.01", "KODE" : "ST168","MATA KULIAH" : "BIG DATA DAN DATA MINING","KELAS" : "21S1BCI-BigData1(ST168)"},
    {"HARI" : "JUMAT","JAM" : "07:00 - 08:40","RUANG" : "L 2.4.3", "KODE" : "ST168","MATA KULIAH" : "BIG DATA DAN DATA MINING","KELAS" : "21S1BCI-BigData1(ST168)"},
    {"HARI" : "JUMAT","JAM" : "13:20 - 15:00","RUANG" : "L 2.4.3", "KODE" : "ST168","MATA KULIAH" : "BIG DATA DAN DATA MINING","KELAS" : "21S1IF-BigData1(ST168)"},
    {"HARI" : "JUMAT","JAM" : "15:30 - 17:10","RUANG" : "L 2.4.3", "KODE" : "ST168","MATA KULIAH" : "BIG DATA DAN DATA MINING","KELAS" : "21S1IF-BigData2(ST168)"},
]

df = pd.DataFrame(jadwalPraktikum)
df
# Out:
#      HARI            JAM     RUANG   KODE               MATA KULIAH  \
# 0  SELASA  08:50 - 10:30  07.01.02  ST168  BIG DATA DAN DATA MINING
# 1  SELASA  10:40 - 12:20  07.02.01  ST168  BIG DATA DAN DATA MINING
# 2  SELASA  12:20 - 15:00  06.02.01  ST168  BIG DATA DAN DATA MINING
# 3   JUMAT  07:00 - 08:40   L 2.4.3  ST168  BIG DATA DAN DATA MINING
# 4   JUMAT  13:20 - 15:00   L 2.4.3  ST168  BIG DATA DAN DATA MINING
# 5   JUMAT  15:30 - 17:10   L 2.4.3  ST168  BIG DATA DAN DATA MINING
#
#                      KELAS
# 0   21S1IF-BigData2(ST168)
# 1   21S1IF-BigData1(ST168)
# 2  21S1BCI-BigData1(ST168)
# 3  21S1BCI-BigData1(ST168)
# 4   21S1IF-BigData1(ST168)
# 5   21S1IF-BigData2(ST168)

# %%
# Nomer 5.b
df[['HARI','JAM','RUANG','KELAS']]
# Out:
#      HARI            JAM     RUANG                    KELAS
# 0  SELASA  08:50 - 10:30  07.01.02   21S1IF-BigData2(ST168)
# 1  SELASA  10:40 - 12:20  07.02.01   21S1IF-BigData1(ST168)
# 2  SELASA  12:20 - 15:00  06.02.01  21S1BCI-BigData1(ST168)
# 3   JUMAT  07:00 - 08:40   L 2.4.3  21S1BCI-BigData1(ST168)
# 4   JUMAT  13:20 - 15:00   L 2.4.3   21S1IF-BigData1(ST168)
# 5   JUMAT  15:30 - 17:10   L 2.4.3   21S1IF-BigData2(ST168)

# %%
# Nomer 5.c
df[(df['JAM'] == '13:20 - 15:00') & (df['RUANG'] == 'L 2.4.3')][['JAM','RUANG']]
# Out:
#              JAM    RUANG
# 4  13:20 - 15:00  L 2.4.3
